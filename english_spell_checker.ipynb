# %% [markdown]
# #Step of implementing an autocorrect system
#
#
# 1.   Identify the mispelled word.
# 2.   Find string that are n edit distance away from the mispelled word.
# 3.   Filter suggested candidates to retain only the ones found in the vocabulary.
# 4.   Order filtered candidates based on word probabilities.
# 5.   Choose the most likely candidate.

# %% [markdown]
# #Identifying a mispelled word
# A word is mispelled if it is not found on the vocabulary of the corpus of text the autocorrect system is working with.

# %% [markdown]
# #Finding string that are n edit distances away
# Editting is an operation performed on a string to change it into another string. An edit distance is a count of the number of operations performed on a word to edit it.
#
# **Types of edit operatins**
#
#
# 1.   INSERT(add a letter).Example "to"=>"top","two"
# 2.   DELETE(remove a letter). Example "hat"=>"at","ha","ht"
# 3.   SWAP(swap 2 adjacent letters). Example "eta"=>"tea","eat"
# 4.   REPLACE(changes one letter to another). Example "jaw"=>"jar","paw"

# %% [markdown]
# # Calculating word probabillities
#
# The probabilities ot a word is calculated based on the following formula: P(w) = C(W)/V where
#
# P(w) is the probability of word,
#
# C(W) is the number of times s word w appears in the corpus
#
# V is the total number of words in the corpus

# %% [markdown]
# # Minimum edit distance
#
# Minimum edit distance is the least number of edits needed to transform one string into another.

# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename,"r") as file:
    lines = file.readlines()
    words = []

    for line in lines:
      words += re.findall(r'\w+',line.lower())
  return words

# %%
words = read_corpus("/content/drive/MyDrive/shakespeare.txt")
print(f"corpus total words {len(words)}")
# Out:
# corpus total words 927610

# %%
vocab = set(words)
print(f"unique total words{len(vocab)}")
# Out:
# unique total words23723

# %%
word_counts = Counter(words)
print(word_counts["shakespeare"])
# Out:
# 254

# %% [markdown]
# # Word Probabilities

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["shakespeare"])
# Out:
# 0.000273821972596242

# %%
def split(word):
  return [(word[:i],word[i:]) for i in range(len(word)+1)]

# %%
print(split("school"))
# Out:
# [('', 'school'), ('s', 'chool'), ('sc', 'hool'), ('sch', 'ool'), ('scho', 'ol'), ('schoo', 'l'), ('school', '')]

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [left + centre + right for left, right in split(word) for centre in letters]

# %%
print(insert("school"))
print(len(insert("school")))
# Out:
# ['aschool', 'bschool', 'cschool', 'dschool', 'eschool', 'fschool', 'gschool', 'hschool', 'ischool', 'jschool', 'kschool', 'lschool', 'mschool', 'nschool', 'oschool', 'pschool', 'qschool', 'rschool', 'sschool', 'tschool', 'uschool', 'vschool', 'wschool', 'xschool', 'yschool', 'zschool', 'sachool', 'sbchool', 'scchool', 'sdchool', 'sechool', 'sfchool', 'sgchool', 'shchool', 'sichool', 'sjchool', 'skchool', 'slchool', 'smchool', 'snchool', 'sochool', 'spchool', 'sqchool', 'srchool', 'sschool', 'stchool', 'suchool', 'svchool', 'swchool', 'sxchool', 'sychool', 'szchool', 'scahool', 'scbhool', 'scchool', 'scdhool', 'scehool', 'scfhool', 'scghool', 'schhool', 'scihool', 'scjhool', 'sckhool', 'sclhool', 'scmhool', 'scnhool', 'scohool', 'scphool', 'scqhool', 'scrhool', 'scshool', 'scthool', 'scuhool', 'scvhool', 'scwhool', 'scxhool', 'scyhool', 'sczhool', 'schaool', 'schbool', 'schcool', 'schdool', 'scheool', 'schfool', 'schgool', 'schhool', 'schiool', 'schjool', 'schkool', 'schlool', 'schmool', 'schnool', 'schoool', 'schpool', 'schqool', 'schrool', 'schsool', 'schtool', 'schuool', 'schvool', 'schwool', 'schxool', 'schyool', 'schzool', 'schoaol', 'schobol', 'schocol', 'schodol', 'schoeol', 'schofol', 'schogol', 'schohol', 'schoiol', 'schojol', 'schokol', 'scholol', 'schomol', 'schonol', 'schoool', 'schopol', 'schoqol', 'schorol', 'schosol', 'schotol', 'schouol', 'schovol', 'schowol', 'schoxol', 'schoyol', 'schozol', 'schooal', 'schoobl', 'schoocl', 'schoodl', 'schooel', 'schoofl', 'schoogl', 'schoohl', 'schooil', 'schoojl', 'schookl', 'schooll', 'schooml', 'schoonl', 'schoool', 'schoopl', 'schooql', 'schoorl', 'schoosl', 'schootl', 'schooul', 'schoovl', 'schoowl', 'schooxl', 'schooyl', 'schoozl', 'schoola', 'schoolb', 'schoolc', 'schoold', 'schoole', 'schoolf', 'schoolg', 'schoolh', 'schooli', 'schoolj', 'schoolk', 'schooll', 'schoolm', 'schooln', 'schoolo', 'schoolp', 'schoolq', 'schoolr', 'schools', 'schoolt', 'schoolu', 'schoolv', 'schoolw', 'schoolx', 'schooly', 'schoolz']
# 182

# %%
def delete(word):
  return[left + right[1:] for left,right in split(word) if right]

# %%
print(delete("school"))
# Out:
# ['chool', 'shool', 'scool', 'schol', 'schol', 'schoo']

# %%
def swap(word):
  return[left + right[1] + right[0] + right[2:] for left, right in split(word) if len(right)>1]

# %%
print(swap("school"))
# Out:
# ['cshool', 'shcool', 'scohol', 'school', 'scholo']

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [left + centre + right[1:] for left,right in split(word) if right for centre in letters]

# %%
print(replace("school"))
# Out:
# ['achool', 'bchool', 'cchool', 'dchool', 'echool', 'fchool', 'gchool', 'hchool', 'ichool', 'jchool', 'kchool', 'lchool', 'mchool', 'nchool', 'ochool', 'pchool', 'qchool', 'rchool', 'school', 'tchool', 'uchool', 'vchool', 'wchool', 'xchool', 'ychool', 'zchool', 'sahool', 'sbhool', 'school', 'sdhool', 'sehool', 'sfhool', 'sghool', 'shhool', 'sihool', 'sjhool', 'skhool', 'slhool', 'smhool', 'snhool', 'sohool', 'sphool', 'sqhool', 'srhool', 'sshool', 'sthool', 'suhool', 'svhool', 'swhool', 'sxhool', 'syhool', 'szhool', 'scaool', 'scbool', 'sccool', 'scdool', 'sceool', 'scfool', 'scgool', 'school', 'sciool', 'scjool', 'sckool', 'sclool', 'scmool', 'scnool', 'scoool', 'scpool', 'scqool', 'scrool', 'scsool', 'sctool', 'scuool', 'scvool', 'scwool', 'scxool', 'scyool', 'sczool', 'schaol', 'schbol', 'schcol', 'schdol', 'scheol', 'schfol', 'schgol', 'schhol', 'schiol', 'schjol', 'schkol', 'schlol', 'schmol', 'schnol', 'school', 'schpol', 'schqol', 'schrol', 'schsol', 'schtol', 'schuol', 'schvol', 'schwol', 'schxol', 'schyol', 'schzol', 'schoal', 'schobl', 'schocl', 'schodl', 'schoel', 'schofl', 'schogl', 'schohl', 'schoil', 'schojl', 'schokl', 'scholl', 'schoml', 'schonl', 'school', 'schopl', 'schoql', 'schorl', 'schosl', 'schotl', 'schoul', 'schovl', 'schowl', 'schoxl', 'schoyl', 'schozl', 'schooa', 'schoob', 'schooc', 'schood', 'schooe', 'schoof', 'schoog', 'schooh', 'schooi', 'schooj', 'schook', 'school', 'schoom', 'schoon', 'schooo', 'schoop', 'schooq', 'schoor', 'schoos', 'schoot', 'schoou', 'schoov', 'schoow', 'schoox', 'schooy', 'schooz']

# %%
def level_one_edits(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(level_one_edits("school"))
# Out:
# {'aschool', 'schozl', 'ischool', 'qschool', 'schoxl', 'schoou', 'schdool', 'schfol', 'schoal', 'spchool', 'schkol', 'schosol', 'schoosl', 'schobl', 'sccool', 'schooyl', 'xschool', 'gschool', 'schooil', 'schools', 'sphool', 'uschool', 'schoolm', 'schooel', 'schiool', 'schojl', 'school', 'schoolz', 'sochool', 'schoor', 'eschool', 'snchool', 'schcol', 'schooml', 'svhool', 'schqool', 'schofl', 'schiol', 'scihool', 'shcool', 'schokl', 'fschool', 'schwol', 'schoolj', 'jchool', 'sthool', 'schoos', 'schooz', 'schoorl', 'scchool', 'schoom', 'schooll', 'scuool', 'scrool', 'scphool', 'scqhool', 'szhool', 'shchool', 'jschool', 'rchool', 'schbool', 'schyol', 'srchool', 'schooa', 'schqol', 'schovl', 'schfool', 'mchool', 'schcool', 'srhool', 'schooy', 'schooq', 'schoxol', 'schoowl', 'szchool', 'schoobl', 'slchool', 'schoiol', 'schaol', 'schomol', 'sychool', 'sschool', 'scheool', 'schooly', 'schocl', 'schooo', 'schovol', 'schoozl', 'schoocl', 'sdhool', 'lchool', 'scbool', 'kchool', 'sfhool', 'schohl', 'schvol', 'schooi', 'schoolq', 'kschool', 'sczool', 'schrool', 'schlol', 'schoul', 'schoo', 'schoogl', 'sfchool', 'scohool', 'schxool', 'scuhool', 'bschool', 'vchool', 'sciool', 'schsool', 'sechool', 'schzol', 'scbhool', 'hchool', 'mschool', 'snhool', 'schooj', 'scnool', 'scmhool', 'sghool', 'schooh', 'scholol', 'schoqol', 'schogol', 'schoog', 'schonl', 'schook', 'schoot', 'schoox', 'schohol', 'sihool', 'schmool', 'schhol', 'scfool', 'schxol', 'sdchool', 'schoil', 'schooli', 'scxool', 'cchool', 'schtol', 'schol', 'sbhool', 'schofol', 'schorl', 'schotl', 'schuol', 'schbol', 'swhool', 'schookl', 'schootl', 'schooln', 'scwool', 'schpool', 'scghool', 'schowol', 'schkool', 'smhool', 'schoold', 'scoool', 'schaool', 'schoolv', 'schoopl', 'schooul', 'schodl', 'cschool', 'schpol', 'pschool', 'scthool', 'schoolt', 'schoon', 'schosl', 'schoolr', 'schsol', 'stchool', 'schocol', 'qchool', 'schgool', 'slhool', 'scjhool', 'tchool', 'ychool', 'schoolp', 'zchool', 'sqhool', 'schoool', 'sbchool', 'scohol', 'scvool', 'scsool', 'schodol', 'scxhool', 'chool', 'scholo', 'scwhool', 'lschool', 'sqchool', 'sichool', 'scaool', 'schoov', 'scehool', 'scshool', 'schnool', 'schoaol', 'schoolk', 'nchool', 'schnol', 'skchool', 'schoolh', 'schowl', 'schhool', 'vschool', 'schwool', 'schood', 'wchool', 'sclool', 'sjchool', 'xchool', 'scholl', 'dchool', 'uchool', 'sxhool', 'schoob', 'schoop', 'schonol', 'schlool', 'scheol', 'shhool', 'scmool', 'schoolo', 'schyool', 'schoolc', 'schdol', 'schoolb', 'scool', 'schogl', 'schoeol', 'schoolx', 'scyool', 'schotol', 'syhool', 'schoojl', 'ichool', 'schooql', 'suhool', 'gchool', 'schoow', 'fchool', 'bchool', 'sceool', 'schooal', 'schtool', 'sxchool', 'sahool', 'echool', 'hschool', 'achool', 'schoof', 'sjhool', 'schopl', 'schobol', 'scdhool', 'schoolu', 'zschool', 'schoodl', 'schoola', 'schorol', 'scahool', 'oschool', 'schmol', 'schoonl', 'schjool', 'schoel', 'tschool', 'schoole', 'schokol', 'schooc', 'schooxl', 'schjol', 'skhool', 'sczhool', 'schoyol', 'pchool', 'smchool', 'schoofl', 'schoql', 'scdool', 'rschool', 'schoohl', 'cshool', 'schoml', 'sckool', 'schoyl', 'schvool', 'sachool', 'scgool', 'scnhool', 'scqool', 'scpool', 'scjool', 'scyhool', 'suchool', 'wschool', 'scrhool', 'schgol', 'sclhool', 'sshool', 'sehool', 'schozol', 'schoolg', 'schzool', 'sohool', 'schooe', 'nschool', 'swchool', 'schouol', 'scvhool', 'sctool', 'svchool', 'schoovl', 'ochool', 'schuool', 'schrol', 'sckhool', 'schoolf', 'scfhool', 'schopol', 'shool', 'yschool', 'dschool', 'sgchool', 'schoolw', 'schojol'}

# %% [markdown]
# chennal model probability

# %%
misspell_words = level_one_edits("school")
total_misspelled_word_count = float(len(misspell_words))
word_count_dict = {}
for word in misspell_words:
    if word in word_count_dict:
        word_count_dict[word] += 1
    else:
        word_count_dict[word] = 1

chennal_model_word_probas = {word: count / total_misspelled_word_count for word, count in word_count_dict.items()}

# %%
chennal_model_word_probas

# %%
print(chennal_model_word_probas["aschool"])
# Out:
# 0.002976190476190476

# %%
def level_two_edits(word):
  return set(e2 for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits("school"))
# Out:
# {'schocqol', 'schsooll', 'schoid', 'cjool', 'skcfhool', 'cchosl', 'skchoou', 'schtooml', 'schoorr', 'scpsol', 'schobofl', 'scmooa', 'sczooq', 'bwchool', 'schopfol', 'schzooe', 'schoodu', 'scdoiol', 'schoyg', 'lschoonl', 'schopolf', 'sbcdool', 'mcvool', 'sahoul', 'scjhoovl', 'hschoolx', 'schozbol', 'sdchoou', 'sxchoowl', 'suholl', 'schuoold', 'bschoolh', 'cxhool', 'vschotl', 'gschoxl', 'sxchoola', 'schhrol', 'schobvl', 'ssqhool', 'csheol', 'schonlr', 'scshnool', 'schdoosl', 'pcqhool', 'scoihool', 'iciool', 'snchogol', 'schoowpl', 'wschpool', 'scfgool', 'jchoml', 'dschoolz', 'oschoox', 'gwchool', 'sczjol', 'lschyool', 'hschbool', 'cschfool', 'sachooxl', 'schonlw', 'seohol', 'sjcdool', 'scaxol', 'showol', 'schvoy', 'vhschool', 'schmoolr', 'scrhooln', 'eschoobl', 'fwhool', 'schoolmv', 'wsychool', 'sqhoos', 'schoepl', 'sdchoovl', 'sclhojol', 'scehoolm', 'smhoovl', 'hscool', 'fchoolk', 'fchrol', 'ntschool', 'schuooh', 'zschoos', 'achogol', 'seyool', 'smcvhool', 'echopl', 'schzonl', 'scaofol', 'jshool', 'scgoqol', 'zschoojl', 'schrhol', 'opchool', 'schoex', 'acnhool', 'schioog', 'slrchool', 'sctooal', 'scphol', 'syhsool', 'wschooh', 'aschoxl', 'zschcool', 'scjooo', 'lchorol', 'schaokol', 'gchood', 'schodox', 'zghool', 'yschooly', 'swcjool', 'sychorl', 'wschooel', 'schoinl', 'scxhooe', 'sohoolc', 'aschooe', 'mchonl', 'schoiy', 'smhooql', 'uchoolc', 'pschooy', 'dchiool', 'schvoml', 'cchtol', 'sclhodl', 'pscgool', 'aschoolp', 'schholk', 'kjschool', 'schojel', 'lschoolz', 'ochodol', 'schholy', 'rchnool', 'schzoolb', 'gschoob', 'scxhowl', 'schgoc', 'schojx', 'sochzool', 'sfeool', 'nchoeol', 'sshoal', 'scdhooh', 'rschnol', 'schonal', 'schoyod', 'schowozl', 'fschogl', 'scuhoolj', 'scqhoqol', 'sqhokol', 'schobold', 'schoolhc', 'schozdl', 'jchooln', 'schoopvl', 'schetol', 'seholo', 'schrocl', 'scfhuol', 'pschooil', 'scdooz', 'schovl', 'scjdool', 'schoytol', 'schoeolc', 'szhoou', 'schgwool', 'zschokl', 'scroom', 'oschooel', 'wchookl', 'scloeol', 'scyooln', 'chotl', 'saholol', 'schfooln', 'schooax', 'dchoogl', 'sihoolb', 'pccool', 'sqhoel', 'suchjol', 'qcmool', 'schmoor', 'spcaool', 'swchiol', 'svchomol', 'achoel', 'nchhol', 'scnorol', 'schoobbl', 'suhoolj', 'sjcnool', 'schoolnr', 'schaok', 'cshooql', 'schdozol', 'qgschool', 'bcthool', 'sjchoolh', 'shhooa', 'schoolii', 'schmrl', 'scxhooxl', 'srchoobl', 'vychool', 'smhxool', 'sohiool', 'kphool', 'suhoolp', 'shcooal', 'schoesl', 'jschoolg', 'scfooal', 'scxhoil', 'nmchool', 'sjhlol', 'sschorol', 'ychoool', 'echcol', 'scoholp', 'sczoaol', 'mghool', 'schooclu', 'dschocl', 'scphodol', 'pchogol', 'sfhogol', 'scthoog', 'lzhool', 'sxchovl', 'scohl', 'schwolol', 'scevool', 'scpoov', 'jchvol', 'smchkol', 'sdcvool', 'sfhool', 'smcmool', 'scaqol', 'schnoll', 'sbchfol', 'schogoi', 'scghokol', 'srhoon', 'schuodl', 'xschoopl', 'sqhqol', 'nschorol', 'sfhooly', 'fchooc', 'sghoos', 'sqhoolj', 'sohoxol', 'skdhool', 'schoglr', 'zchoeol', 'gchcool', 'scvwol', 'oschmol', 'pcholol', 'svchoodl', 'schoopd', 'kschmool', 'sxchmol', 'schcolo', 'scmhuol', 'schaoolf', 'sihol', 'srchqool', 'schoteol', 'sdhodl', 'ichvool', 'schfmol', 'uchorol', 'scdookl', 'schcgool', 'zcmhool', 'sgckool', 'schqokol', 'schozols', 'schoosal', 'schjolz', 'sychhool', 'osvhool', 'schoolwr', 'qcsool', 'schohols', 'schpwol', 'fchoob', 'scjokol', 'scoop', 'sschsool', 'scoo', 'sgholol', 'sahohl', 'sghhol', 'tsnhool', 'sgcfhool', 'seqchool', 'bchoog', 'echoll', 'scooml', 'schojkl', 'sdhofol', 'shoofl', 'ohchool', 'gscihool', 'ichooc', 'schszool', 'slhmol', 'scerol', 'schhohol', 'hnhool', 'siichool', 'schpod', 'gvchool', 'tschuol', 'yctool', 'pschoow', 'hschooml', 'scshsol', 'scjhoolk', 'hchbol', 'schbolt', 'suhokol', 'xchoole', 'wgschool', 'sczhozl', 'wchoofl', 'xchooly', 'qschooql', 'scahoosl', 'zschoold', 'scioolf', 'schakl', 'zjhool', 'achtol', 'scphoo', 'sdchfool', 'cschojl', 'schcdol', 'smhoov', 'schoolbp', 'suhoolm', 'sbhoql', 'schrzl', 'chook', 'uchoel', 'sclbhool', 'slchofl', 'schoopn', 'schmomol', 'schoijl', 'scoholx', 'bscpool', 'scykool', 'sc ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
      print(f"{word} is already correctly spelt")
      return

    suggestions = level_one_edits(word) or level_two_edits(word) or [word]
    best_guesses = [w for w in suggestions if w in vocabulary]
    return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "caol"
guesses = correct_spelling(word, vocab, word_probas)
print(guesses)
# Out:
# [('carol', 2.156078524379858e-06), ('col', 2.156078524379858e-06), ('carl', 1.078039262189929e-06), ('cool', 3.773137417664751e-05), ('coal', 1.6170588932848933e-05), ('gaol', 6.468235573139574e-06), ('call', 0.0008117635644290165)]
